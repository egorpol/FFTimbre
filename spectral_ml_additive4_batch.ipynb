# %% [markdown]
# # Batch Optimization (Additive)
#
# Run multiple optimizer/metric jobs in a batch for additive resynthesis using `py_scripts/additive_synth_opt.py`.
# Outputs use the same naming scheme (audio, TSV, plots) as in the single-run additive notebook and FM batch notebook.

# %%
# Setup and target loading
import os
from pathlib import Path
import numpy as np
import pandas as pd
from IPython.display import display

import matplotlib.pyplot as plt

from py_scripts.additive_synth_opt import (
    AdditiveObjective, additive_synth,
    run_de_optimization, run_dual_annealing, run_basinhopping,
    save_and_display_final_values_additive, make_fft
)
from py_scripts.waveform_generators import sine_wave, square_wave, triangle_wave, sawtooth_wave, noise_wave
from py_scripts.fm_synth_opt import save_wav

# Unified config
SR = 44100
DURATION = 2.0
FFT_PAD = 2
WAVEFORM_DTYPE = 'float32'  # 'float32' or 'float64'
FADE_IN_MS = 10.0
FADE_OUT_MS = 10.0

# Additive-specific
N_PARTIALS = 4  # number of oscillators/partials
USE_WAVEFORMS = True
waveforms = [sine_wave, square_wave, triangle_wave, sawtooth_wave, noise_wave]

# Load target partials (TSV)
target_path = 'tsv/cello_single.tsv'
df = pd.read_csv(target_path, sep='\t')
display(df)
target_freqs = df['Frequency (Hz)'].to_numpy()
# Normalize amplitudes to max=1 for stable objectives
target_amps = (df['Amplitude'] / df['Amplitude'].max()).to_numpy()
target_name = Path(target_path).stem

# Helper: run one additive optimization (delegates to py_scripts)
from py_scripts.additive_batch import run_one_additive as _run_additive_core, RunAdditiveConfig

def run_one_additive(
    *,
    method: str,
    metric: str,
    optimizer_kwargs: dict = None,
    sr: int = SR,
    duration: float = DURATION,
    fft_pad: int = FFT_PAD,
    fade_in_ms: float = FADE_IN_MS,
    fade_out_ms: float = FADE_OUT_MS,
    seed: int | None = 42,
):
    cfg = RunAdditiveConfig(
        target_freqs=target_freqs,
        target_amps=target_amps,
        target_name=target_name,
        n_partials=N_PARTIALS,
        use_waveforms=USE_WAVEFORMS,
        waveforms=tuple(waveforms),
        sr=sr,
        duration=duration,
        fft_pad=fft_pad,
        waveform_dtype=WAVEFORM_DTYPE,
        fade_in_ms=fade_in_ms,
        fade_out_ms=fade_out_ms,
        method=method,
        metric=metric,
        optimizer_kwargs=(optimizer_kwargs or {}),
        seed=seed,
    )
    return _run_additive_core(cfg)
# Out:
#     Frequency (Hz)  Amplitude
# 0        73.684211   0.005356
# 1       136.842105   0.004395
# 2       147.368421   0.102953
# 3       223.684211   0.011307
# 4       297.368421   0.035448
# 5       371.052632   0.005977
# 6       442.105263   0.002880
# 7       447.368421   0.006474
# 8       521.052632   0.011020
# 9       594.736842   0.002818
# 10      818.421053   0.002759
# 11      894.736842   0.002141
# 12      965.789474   0.002436
# 13     1263.157895   0.002615

# %% [markdown]
# ## Define batch jobs
# - `method`: one of `'de'` (Differential Evolution), `'da'` (Dual Annealing), `'bh'` (Basin Hopping).
# - `metric`: any supported metric: `'pearson'`, `'mfcc'`, `'itakura_saito'`, `'spectral_convergence'`, `'cosine'`, `'euclidean'`, `'manhattan'`, `'kl'`.
# - `kwargs`: optimizer-specific settings (e.g., `maxiter`, `workers`, `stepsize`).

# %%
jobs = [
    # Pearson
    dict(method='de', metric='pearson', kwargs=dict(maxiter=500, popsize=20, workers=-1)),
    dict(method='da', metric='pearson', kwargs=dict(maxiter=500)),
    dict(method='bh', metric='pearson', kwargs=dict(maxiter=500, stepsize=0.5)),
    # MFCC
    dict(method='de', metric='mfcc', kwargs=dict(maxiter=500, popsize=20, workers=-1)),
    dict(method='da', metric='mfcc', kwargs=dict(maxiter=500)),
    dict(method='bh', metric='mfcc', kwargs=dict(maxiter=500, stepsize=0.5)),
    # Spectral Convergence
    dict(method='de', metric='itakura_saito', kwargs=dict(maxiter=500, popsize=20, workers=-1)),
    dict(method='da', metric='itakura_saito', kwargs=dict(maxiter=500)),
    dict(method='bh', metric='itakura_saito', kwargs=dict(maxiter=500, stepsize=0.5)),
    # Cosine
    dict(method='de', metric='spectral_convergence', kwargs=dict(maxiter=500, popsize=20, workers=-1)),
    dict(method='da', metric='spectral_convergence', kwargs=dict(maxiter=500)),
    dict(method='bh', metric='spectral_convergence', kwargs=dict(maxiter=500, stepsize=0.5)),

    dict(method='de', metric='cosine', kwargs=dict(maxiter=500, popsize=20, workers=-1)),
    dict(method='da', metric='cosine', kwargs=dict(maxiter=500)),
    dict(method='bh', metric='cosine', kwargs=dict(maxiter=500, stepsize=0.5)),
    # Euclidean
    dict(method='de', metric='euclidean', kwargs=dict(maxiter=500, popsize=20, workers=-1)),
    dict(method='da', metric='euclidean', kwargs=dict(maxiter=500)),
    dict(method='bh', metric='euclidean', kwargs=dict(maxiter=500, stepsize=0.5)),
    # Manhattan
    dict(method='de', metric='manhattan', kwargs=dict(maxiter=500, popsize=20, workers=-1)),
    dict(method='da', metric='manhattan', kwargs=dict(maxiter=500)),
    dict(method='bh', metric='manhattan', kwargs=dict(maxiter=500, stepsize=0.5)),
    # KL
    dict(method='de', metric='kl', kwargs=dict(maxiter=500, popsize=20, workers=-1)),
    dict(method='da', metric='kl', kwargs=dict(maxiter=500)),
    dict(method='bh', metric='kl', kwargs=dict(maxiter=500, stepsize=0.5))
]

rows = []
for j in jobs:
    info = run_one_additive(method=j['method'], metric=j['metric'], optimizer_kwargs=j.get('kwargs') or {})
    rows.append(info)

summary = pd.DataFrame([{
    'method': r['method'],
    'metric': r['metric'],
    'best': r['best'],
    'wav_path': r['wav_path'],
    'tsv_path': r['tsv_path'],
} for r in rows])
display(summary)
# Out:
# Additive 4-osc DE → Pearson:   0%|           0/500 [ETA: ?, Elapsed: 00:00]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 38
#      36 rows = []
#      37 for j in jobs:
# ---> 38     info = run_one_additive(method=j['method'], metric=j['metric'], optimizer_kwargs=j.get('kwargs') or {})
#      39     rows.append(info)
#      41 summary = pd.DataFrame([{
#      42     'method': r['method'],
#      43     'metric': r['metric'],
#    (...)
#      46     'tsv_path': r['tsv_path'],
#      47 } for r in rows])
#
# Cell In[1], line 73, in run_one_additive(method, metric, optimizer_kwargs, sr, duration, fft_pad, fade_in_ms, fade_out_ms, seed)
#      43 def run_one_additive(
#      44     *,
#      45     method: str,
#    (...)
#      53     seed: int | None = 42,
#      54 ):
#      55     cfg = RunAdditiveConfig(
#      56         target_freqs=target_freqs,
#      57         target_amps=target_amps,
#    (...)
#      71         seed=seed,
#      72     )
# ---> 73     return _run_additive_core(cfg)
#
# File c:\Users\egorp\Nextcloud\code\public_repos\FFTimbre\py_scripts\additive_batch.py:115, in run_one_additive(cfg)
#     111 if cfg.method == "de":
#     112     optimizer_kwargs.setdefault(
#     113         "tqdm_desc", f"Additive {cfg.n_partials}-osc DE → {str(cfg.metric).title()}"
#     114     )
# --> 115     result, history = run_de_optimization(obj, bounds, seed=cfg.seed, **optimizer_kwargs)
#     116 elif cfg.method == "da":
#     117     optimizer_kwargs.setdefault(
#     118         "tqdm_desc", f"Additive {cfg.n_partials}-osc DA → {str(cfg.metric).title()}"
#     119     )
#
# File c:\Users\egorp\Nextcloud\code\public_repos\FFTimbre\py_scripts\fm_synth_opt.py:339, in run_de_optimization(objective, bounds, maxiter, popsize, tol, mutation, recombination, strategy, workers, seed, tqdm_desc)
#     336 if workers is not None and workers != 1:
#     337     kwargs.update(dict(workers=workers, updating="deferred"))
# --> 339 result = differential_evolution(objective, bounds, **kwargs)
#     340 bar.close()
#     341 return result, error_history
#
# File c:\Users\egorp\miniconda3\envs\py3124t\Lib\site-packages\scipy\optimize\_differentialevolution.py:503, in differential_evolution(func, bounds, args, strategy, maxiter, popsize, tol, mutation, recombination, seed, callback, disp, polish, init, atol, updating, workers, constraints, x0, integrality, vectorized)
#     486 # using a context manager means that any created Pool objects are
#     487 # cleared up.
#     488 with DifferentialEvolutionSolver(func, bounds, args=args,
#     489                                  strategy=strategy,
#     490                                  maxiter=maxiter,
#    (...)
#     501                                  integrality=integrality,
#     502                                  vectorized=vectorized) as solver:
# --> 503     ret = solver.solve()
#     505 return ret
#
# File c:\Users\egorp\miniconda3\envs\py3124t\Lib\site-packages\scipy\optimize\_differentialevolution.py:1168, in DifferentialEvolutionSolver.solve(self)
#    1165 for nit in range(1, self.maxiter + 1):
#    1166     # evolve the population by a generation
#    1167     try:
# -> 1168         next(self)
#    1169     except StopIteration:
#    1170         warning_flag = True
#
# File c:\Users\egorp\miniconda3\envs\py3124t\Lib\site-packages\scipy\optimize\_differentialevolution.py:1623, in DifferentialEvolutionSolver.__next__(self)
#    1620 trial_energies = np.full(self.num_population_members, np.inf)
#    1622 # only calculate for feasible entries
# -> 1623 trial_energies[feasible] = self._calculate_population_energies(
#    1624     trial_pop[feasible])
#    1626 # which solutions are 'improved'?
#    1627 loc = [self._accept_trial(*val) for val in
#    1628        zip(trial_energies, feasible, cv, self.population_energies,
#    1629            self.feasible, self.constraint_violation)]
#
# File c:\Users\egorp\miniconda3\envs\py3124t\Lib\site-packages\scipy\optimize\_differentialevolution.py:1320, in DifferentialEvolutionSolver._calculate_population_energies(self, population)
#    1317 parameters_pop = self._scale_parameters(population)
#    1318 try:
#    1319     calc_energies = list(
# -> 1320         self._mapwrapper(self.func, parameters_pop[0:S])
#    1321     )
#    1322     calc_energies = np.squeeze(calc_energies)
#    1323 except (TypeError, ValueError) as e:
#    1324     # wrong number of arguments for _mapwrapper
#    1325     # or wrong length returned from the mapper
#
# File c:\Users\egorp\miniconda3\envs\py3124t\Lib\site-packages\scipy\_lib\_util.py:511, in MapWrapper.__call__(self, func, iterable)
#     508 def __call__(self, func, iterable):
#     509     # only accept one iterable because that's all Pool.map accepts
#     510     try:
# --> 511         return self._mapfunc(func, iterable)
#     512     except TypeError as e:
#     513         # wrong number of arguments
#     514         raise TypeError("The map-like callable must be of the"
#     515                         " form f(func, iterable)") from e
#
# File c:\Users\egorp\miniconda3\envs\py3124t\Lib\multiprocessing\pool.py:367, in Pool.map(self, func, iterable, chunksize)
#     362 def map(self, func, iterable, chunksize=None):
#     363     '''
#     364     Apply `func` to each element in `iterable`, collecting the results
#     365     in a list that is returned.
#     366     '''
# --> 367     return self._map_async(func, iterable, mapstar, chunksize).get()
#
# File c:\Users\egorp\miniconda3\envs\py3124t\Lib\multiprocessing\pool.py:768, in ApplyResult.get(self, timeout)
#     767 def get(self, timeout=None):
# --> 768     self.wait(timeout)
#     769     if not self.ready():
#     770         raise TimeoutError
#
# File c:\Users\egorp\miniconda3\envs\py3124t\Lib\multiprocessing\pool.py:765, in ApplyResult.wait(self, timeout)
#     764 def wait(self, timeout=None):
# --> 765     self._event.wait(timeout)
#
# File c:\Users\egorp\miniconda3\envs\py3124t\Lib\threading.py:655, in Event.wait(self, timeout)
#     653 signaled = self._flag
#     654 if not signaled:
# --> 655     signaled = self._cond.wait(timeout)
#     656 return signaled
#
# File c:\Users\egorp\miniconda3\envs\py3124t\Lib\threading.py:355, in Condition.wait(self, timeout)
#     353 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     354     if timeout is None:
# --> 355         waiter.acquire()
#     356         gotit = True
#     357     else:
#
# KeyboardInterrupt:
